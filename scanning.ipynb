# %%
# %pip install boto3
# Out:
# Requirement already satisfied: boto3 in c:\orange\lib\site-packages (1.26.110)
# Requirement already satisfied: botocore<1.30.0,>=1.29.110 in c:\orange\lib\site-packages (from boto3) (1.29.110)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in c:\orange\lib\site-packages (from boto3) (0.6.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\orange\lib\site-packages (from boto3) (1.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\orange\lib\site-packages (from botocore<1.30.0,>=1.29.110->boto3) (1.26.9)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\orange\lib\site-packages (from botocore<1.30.0,>=1.29.110->boto3) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\orange\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.30.0,>=1.29.110->boto3) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Copyright 2018 Amazon.com, Inc. or its affiliates. All Rights Reserved.
# PDX-License-Identifier: MIT-0 (For details, see https://github.com/awsdocs/amazon-rekognition-developer-guide/blob/master/LICENSE-SAMPLECODE.)

import boto3

def detect_text(photo, bucket):

    session = boto3.Session(profile_name='user1')
    client = session.client('rekognition')

    response = client.detect_text(Image={'S3Object': {'Bucket': bucket, 'Name': photo}})

    textDetections = response['TextDetections']
    print('Detected text\n----------')
    for text in textDetections:
        print('Detected text:' + text['DetectedText'])
        print('Confidence: ' + "{:.2f}".format(text['Confidence']) + "%")
        print('Id: {}'.format(text['Id']))
        if 'ParentId' in text:
            print('Parent Id: {}'.format(text['ParentId']))
        print('Type:' + text['Type'])
        print()
    return len(textDetections)

def main():
    bucket = 'id-picture-1-for-scanning'
    photo = 'id-pic-1.jpg'
    text_count = detect_text(photo, bucket)
    print("Text detected: " + str(text_count))

if __name__ == "__main__":
    main()
# Out:
# Detected text
# ----------
# Detected text:BUNDESREPUBLIK DEUTSCHLAND
# Confidence: 99.79%
# Id: 0
# Type:LINE
#
# Detected text:FEDERAL REPUBLIC OF GERMANY , REPUBLIQUE FEDERALE D'ALLEMAGNE
# Confidence: 90.33%
# Id: 1
# Type:LINE
#
# Detected text:L01X00T47
# Confidence: 97.57%
# Id: 2
# Type:LINE
#
# Detected text:DE
# Confidence: 100.00%
# Id: 3
# Type:LINE
#
# Detected text:PERSONALAUSWEIS
# Confidence: 99.77%
# Id: 4
# Type:LINE
#
# Detected text:IDENTITY CARD/CARTE D'IDENTITE
# Confidence: 98.44%
# Id: 5
# Type:LINE
#
# Detected text:[a] Name/Surname/Nom
# Confidence: 99.15%
# Id: 6
# Type:LINE
#
# Detected text:[b] Geburtsname/Name at birth/Nom de naissance
# Confidence: 99.47%
# Id: 7
# Type:LINE
#
# Detected text:[a] MUSTERMANN
# Confidence: 99.31%
# Id: 8
# Type:LINE
#
# Detected text:[b] GABLER
# Confidence: 99.74%
# Id: 9
# Type:LINE
#
# Detected text:Vornamen/Given names/Prenoms
# Confidence: 97.61%
# Id: 10
# Type:LINE
#
# Detected text:ERIKA
# Confidence: 100.00%
# Id: 11
# Type:LINE
#
# Detected text:Geburtstag/Date of birth/
# Confidence: 99.13%
# Id: 12
# Type:LINE
#
# Detected text:Date de naissance
# Confidence: 99.18%
# Id: 13
# Type:LINE
#
# Detected text:Nationalite
# Confidence: 75.14%
# Id: 14
# Type:LINE
#
# Detected text:12.08. 1983 DEUTSCH
# Confidence: 98.86%
# Id: 15
# Type:LINE
#
# Detected text:Geburtsort/Place of birth/Lieu de naissance
# Confidence: 99.44%
# Id: 16
# Type:LINE
#
# Detected text:BERLIN
# Confidence: 96.66%
# Id: 17
# Type:LINE
#
# Detected text:Gültig bis/Date of expiry/
# Confidence: 99.57%
# Id: 18
# Type:LINE
#
# Detected text:Date d'expiration
# Confidence: 97.28%
# Id: 19
# Type:LINE
#
# Detected text:938568
# Confidence: 99.92%
# Id: 20
# Type:LINE
#
# Detected text:01. 08.2031
# Confidence: 94.73%
# Id: 21
# Type:LINE
#
# Detected text:BUNDESREPUBLIK
# Confidence: 99.68%
# Id: 22
# Parent Id: 0
# Type:WORD
#
# Detected text:DEUTSCHLAND
# Confidence: 99.89%
# Id: 23
# Parent Id: 0
# Type:WORD
#
# Detected text:FEDERAL
# Confidence: 98.23%
# Id: 24
# Parent Id: 1
# Type:WORD
#
# Detected text:REPUBLIC
# Confidence: 99.88%
# Id: 25
# Parent Id: 1
# Type:WORD
#
# Detected text:OF
# Confidence: 99.50%
# Id: 26
# Parent Id: 1
# Type:WORD
#
# Detected text:GERMANY
# Confidence: 99.56%
# Id: 27
# Parent Id: 1
# Type:WORD
#
# Detected text:,
# Confidence: 30.10%
# Id: 28
# Parent Id: 1
# Type:WORD
#
# Detected text:REPUBLIQUE
# Confidence: 98.87%
# Id: 29
# Parent Id: 1
# Type:WORD
#
# Detected text:FEDERALE
# Confidence: 99.74%
# Id: 30
# Parent Id: 1
# Type:WORD
#
# Detected text:D'ALLEMAGNE
# Confidence: 96.73%
# Id: 31
# Parent Id: 1
# Type:WORD
#
# Detected text:L01X00T47
# Confidence: 97.57%
# Id: 32
# Parent Id: 2
# Type:WORD
#
# Detected text:DE
# Confidence: 100.00%
# Id: 33
# Parent Id: 3
# Type:WORD
#
# Detected text:PERSONALAUSWEIS
# Confidence: 99.77%
# Id: 34
# Parent Id: 4
# Type:WORD
#
# Detected text:IDENTITY
# Confidence: 100.00%
# Id: 35
# Parent Id: 5
# Type:WORD
#
# Detected text:CARD/CARTE
# Confidence: 95.33%
# Id: 36
# Parent Id: 5
# Type:WORD
#
# Detected text:D'IDENTITE
# Confidence: 100.00%
# Id: 37
# Parent Id: 5
# Type:WORD
#
# Detected text:[a]
# Confidence: 99.09%
# Id: 38
# Parent Id: 6
# Type:WORD
#
# Detected text:Name/Surname/Nom
# Confidence: 99.20%
# Id: 39
# Parent Id: 6
# Type:WORD
#
# Detected text:[b]
# Confidence: 99.73%
# Id: 40
# Parent Id: 7
# Type:WORD
#
# Detected text:Geburtsname/Name
# Confidence: 99.00%
# Id: 41
# Parent Id: 7
# Type:WORD
#
# Detected text:at
# Confidence: 99.83%
# Id: 42
# Parent Id: 7
# Type:WORD
#
# Detected text:birth/Nom
# Confidence: 99.01%
# Id: 43
# Parent Id: 7
# Type:WORD
#
# Detected text:de
# Confidence: 99.54%
# Id: 44
# Parent Id: 7
# Type:WORD
#
# Detected text:naissance
# Confidence: 99.72%
# Id: 45
# Parent Id: 7
# Type:WORD
#
# Detected text:[a]
# Confidence: 98.87%
# Id: 46
# Parent Id: 8
# Type:WORD
#
# Detected text:MUSTERMANN
# Confidence: 99.75%
# Id: 47
# Parent Id: 8
# Type:WORD
#
# Detected text:[b]
# Confidence: 99.48%
# Id: 48
# Parent Id: 9
# Type:WORD
#
# Detected text:GABLER
# Confidence: 100.00%
# Id: 49
# Parent Id: 9
# Type:WORD
#
# Detected text:Vornamen/Given
# Confidence: 99.18%
# Id: 50
# Parent Id: 10
# Type:WORD
#
# Detected text:names/Prenoms
# Confidence: 96.04%
# Id: 51
# Parent Id: 10
# Type:WORD
#
# Detected text:ERIKA
# Confidence: 100.00%
# Id: 52
# Parent Id: 11
# Type:WORD
#
# Detected text:Geburtstag/Date
# Confidence: 98.62%
# Id: 53
# Parent Id: 12
# Type:WORD
#
# Detected text:of
# Confidence: 99.92%
# Id: 54
# Parent Id: 12
# Type:WORD
#
# Detected text:birth/
# Confidence: 98.84%
# Id: 55
# Parent Id: 12
# Type:WORD
#
# Detected text:Date
# Confidence: 99.33%
# Id: 56
# Parent Id: 13
# Type:WORD
#
# Detected text:de
# Confidence: 99.70%
# Id: 57
# Parent Id: 13
# Type:WORD
#
# Detected text:naissance
# Confidence: 98.52%
# Id: 58
# Parent Id: 13
# Type:WORD
#
# Detected text:Nationalite
# Confidence: 75.14%
# Id: 59
# Parent Id: 14
# Type:WORD
#
# Detected text:12.08.
# Confidence: 97.08%
# Id: 60
# Parent Id: 15
# Type:WORD
#
# Detected text:1983
# Confidence: 99.81%
# Id: 61
# Parent Id: 15
# Type:WORD
#
# Detected text:DEUTSCH
# Confidence: 99.70%
# Id: 62
# Parent Id: 15
# Type:WORD
#
# Detected text:Geburtsort/Place
# Confidence: 98.97%
# Id: 63
# Parent Id: 16
# Type:WORD
#
# Detected text:of
# Confidence: 99.28%
# Id: 64
# Parent Id: 16
# Type:WORD
#
# Detected text:birth/Lieu
# Confidence: 99.09%
# Id: 65
# Parent Id: 16
# Type:WORD
#
# Detected text:de
# Confidence: 100.00%
# Id: 66
# Parent Id: 16
# Type:WORD
#
# Detected text:naissance
# Confidence: 99.84%
# Id: 67
# Parent Id: 16
# Type:WORD
#
# Detected text:BERLIN
# Confidence: 96.66%
# Id: 68
# Parent Id: 17
# Type:WORD
#
# Detected text:Gültig
# Confidence: 99.96%
# Id: 69
# Parent Id: 18
# Type:WORD
#
# Detected text:bis/Date
# Confidence: 98.82%
# Id: 70
# Parent Id: 18
# Type:WORD
#
# Detected text:of
# Confidence: 99.75%
# Id: 71
# Parent Id: 18
# Type:WORD
#
# Detected text:expiry/
# Confidence: 99.75%
# Id: 72
# Parent Id: 18
# Type:WORD
#
# Detected text:Date
# Confidence: 99.50%
# Id: 73
# Parent Id: 19
# Type:WORD
#
# Detected text:d'expiration
# Confidence: 95.05%
# Id: 74
# Parent Id: 19
# Type:WORD
#
# Detected text:938568
# Confidence: 99.92%
# Id: 75
# Parent Id: 20
# Type:WORD
#
# Detected text:01.
# Confidence: 93.45%
# Id: 76
# Parent Id: 21
# Type:WORD
#
# Detected text:08.2031
# Confidence: 96.02%
# Id: 77
# Parent Id: 21
# Type:WORD
#
# Text detected: 78
